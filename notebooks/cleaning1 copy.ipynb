# %% [markdown]
# **Cleaning Movies Metadata**

# %%
import pandas as pd
import numpy as np

movies = pd.read_csv('C:/Coding Projects/Movie-Recommender-Engine/data/movies_metadata.csv')
id_counts = movies['imdb_id'].value_counts()
id_counts > 1

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB
# C:\Users\imihi\AppData\Local\Temp\ipykernel_22592\4257346944.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv('C:/Coding Projects/Movie-Recommender-Engine/data/movies_metadata.csv')

# %%
duplicate_ids = id_counts[id_counts > 1]
duplicate_ids
# Out:
# imdb_id
# tt1180333    3
# 0            3
# tt0499537    2
# tt0082992    2
# tt0046468    2
# tt0111613    2
# tt0157472    2
# tt0454792    2
# tt0084387    2
# tt0270288    2
# tt0080000    2
# tt0446676    2
# tt0022879    2
# tt0287635    2
# tt0173769    2
# tt0235679    2
# tt0062229    2
# tt0022537    2
# tt1327820    2
# tt0499456    2
# tt1701210    2
# tt0067306    2
# tt0127834    2
# tt1821641    2
# tt0295682    2
# tt1736049    2
# tt0100361    2
# tt2018086    2
# tt2121382    2
# tt2818654    2
# Name: count, dtype: int64

# %%
duplicate_movies = movies[movies['imdb_id'].isin(duplicate_ids.index)]
duplicate_movies.sort_values(by = ['imdb_id', 'id'])
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
# 16167                                              False
# 38871                                              False
# ...                                                  ...
# 23534                                              False
# 24164                                              False
# 45265                                              False
# 33184                                              False
# 40040                                              False
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 16167                   NaN                                 0
# 38871                   NaN                                 0
# ...                     ...                               ...
# 23534                   NaN                           3512454
# 24164                   NaN                                 0
# 45265                   NaN                                 0
# 33184                   NaN                            980000
# 40040                   NaN                            980000
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
# 16167  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 38871  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                  ...
# 23534                      [{'id': 18, 'name': 'Drama'}]
# 24164  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 45265  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 33184  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 40040  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
#
#                                                 homepage          id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01
# 16167                                                NaN       99080
# 38871                                                NaN       99080
# ...                                                  ...         ...
# 23534                                                NaN      110428
# 24164                                                NaN      265189
# 45265                                                NaN      265189
# 33184                                                NaN      298721
# 40040                                                NaN      298721
#
#          imdb_id original_language                            original_title  \
# 19730          0             104.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 29503          0              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]
# 35587          0              82.0  [{'iso_639_1': 'en', 'name': 'English'}]
# 16167  tt0022537                en                                The Viking
# 38871  tt0022537                en                                The Viking
# ...          ...               ...                                       ...
# 23534  tt2018086                fr                      Camille Claudel 1915
# 24164  tt2121382                sv                                    Turist
# 45265  tt2121382                sv                                    Turist
# 33184  tt2818654                th                             รักที่ขอนแก่น
# 40040  tt2818654                th                             รักที่ขอนแก่น
#
#                                                 overview  ... release_date  \
# 19730                                           Released  ...            1
# 29503                                           Released  ...           12
# 35587                                           Released  ...           22
# 16167  Originally called White Thunder, American prod...  ...   1931-06-21
# 38871  Originally called White Thunder, American prod...  ...   1931-06-21
# ...                                                  ...  ...          ...
# 23534  Winter, 1915. Confined by her family to an asy...  ...   2013-03-13
# 24164  While holidaying in the French Alps, a Swedish...  ...   2014-08-15
# 45265  While holidaying in the French Alps, a Swedish...  ...   2014-08-15
# 33184  In a hospital, ten soldiers are being treated ...  ...   2015-09-02
# 40040  In a hospital, ten soldiers are being treated ...  ...   2015-09-02
#
#          revenue runtime                                   spoken_languages  \
# 19730        NaN     NaN                                                NaN
# 29503        NaN     NaN                                                NaN
# 35587        NaN     NaN                                                NaN
# 16167        0.0    70.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 38871        0.0    70.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...          ...     ...                                                ...
# 23534   115860.0    95.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 24164  1359497.0   118.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 45265  1359497.0   118.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 33184        0.0   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 40040        0.0   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#          status                                            tagline  \
# 19730       NaN                                                NaN
# 29503       NaN                                                NaN
# 35587       NaN                                                NaN
# 16167  Released  Actually produced during the Great Newfoundlan...
# 38871  Released  Actually produced during the Great Newfoundlan...
# ...         ...                                                ...
# 23534  Released                                                NaN
# 24164  Released                                                NaN
# 45265  Released                                                NaN
# 33184  Released                                                NaN
# 40040  Released                                                NaN
#
#                        title  video vote_average vote_count
# 19730                    NaN    NaN          NaN        NaN
# 29503                    NaN    NaN          NaN        NaN
# 35587                    NaN    NaN          NaN        NaN
# 16167             The Viking  False          0.0        0.0
# 38871             The Viking  False          0.0        0.0
# ...                      ...    ...          ...        ...
# 23534   Camille Claudel 1915  False          7.0       20.0
# 24164          Force Majeure  False          6.8      255.0
# 45265          Force Majeure  False          6.8      255.0
# 33184  Cemetery of Splendour  False          4.4       50.0
# 40040  Cemetery of Splendour  False          4.4       50.0
#
# [62 rows x 24 columns]

# %%
movies.drop_duplicates(subset = ['imdb_id', 'id'], inplace = True) #Drop duplicate entries based on imdb_id and id

# %%
movies['imdb_id'].value_counts() #Duplicates are removed
# Out:
# imdb_id
# 0            3
# tt0114709    1
# tt0113497    1
# tt0113228    1
# tt0114885    1
#             ..
# tt6209470    1
# tt2028550    1
# tt0303758    1
# tt0008536    1
# tt6980792    1
# Name: count, Length: 45417, dtype: int64

# %%
#Drop rows where id or imdb_id is in an invalid format

movies['id'] = pd.to_numeric(movies['id'], errors = 'coerce')
movies.dropna(subset = ['id'], inplace = True)
movies.dropna(subset = ['imdb_id'], inplace = True)

movies['movie_id'] = movies['id'].astype(int)
movies.drop(columns = ['id'], inplace = True)

# %%
#Drop rows where vote_count, vote_average, or title is missing
movies.dropna(subset = ['vote_count', 'vote_average', 'title'], inplace = True)

# %%
#Rename original_title column to title

movies['title'] = movies['title']
movies.drop(columns = ['original_title'], inplace = True)

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  tt0114709                en
# 1                                   NaN  tt0113497                en
# 2                                   NaN  tt0113228                en
# 3                                   NaN  tt0114885                en
# 4                                   NaN  tt0113041                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495
# 4  Just when George Banks has recovered from his ...   8.387519
#
#                         poster_path  ...      revenue runtime  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg  ...  373554033.0    81.0
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg  ...  262797249.0   104.0
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg  ...          0.0   101.0
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg  ...   81452156.0   127.0
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg  ...   76578911.0   106.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count movie_id
# 0                    Toy Story  False          7.7     5415.0      862
# 1                      Jumanji  False          6.9     2413.0     8844
# 2             Grumpier Old Men  False          6.5       92.0    15602
# 3            Waiting to Exhale  False          6.1       34.0    31357
# 4  Father of the Bride Part II  False          5.7      173.0    11862
#
# [5 rows x 23 columns]

# %%
movies['genres'] = movies['genres'].apply(lambda element: eval(element))

# %%
movies.loc[0, 'genres']
movies['genres'] = movies['genres'].apply(lambda element: [d['name'] for d in element] if isinstance(element, list) else [])

# %%
#Keep overviews
movies.drop(columns = ['belongs_to_collection', 'budget', 'homepage', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'poster_path', 'video', 'original_language', 'adult'], inplace = True)

# %%
movies['overview'] = movies['tagline'].fillna('').str.cat(movies['overview'].fillna(''), sep=' ')
movies.drop(columns = ['tagline'], inplace = True)
movies.head()
# Out:
#                          genres    imdb_id  \
# 0   [Animation, Comedy, Family]  tt0114709
# 1  [Adventure, Fantasy, Family]  tt0113497
# 2             [Romance, Comedy]  tt0113228
# 3      [Comedy, Drama, Romance]  tt0114885
# 4                      [Comedy]  tt0113041
#
#                                             overview  \
# 0   Led by Woody, Andy's toys live happily in his...
# 1  Roll the dice and unleash the excitement! When...
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count  movie_id
# 0                    Toy Story           7.7      5415.0       862
# 1                      Jumanji           6.9      2413.0      8844
# 2             Grumpier Old Men           6.5        92.0     15602
# 3            Waiting to Exhale           6.1        34.0     31357
# 4  Father of the Bride Part II           5.7       173.0     11862

# %%
"""Stem the keywords so there are less features in the TF-IDF matrix"""
import string
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')

movies['overview'] = movies['overview'].str.split()
movies['overview'] = movies['overview'].apply(lambda l: [stemmer.stem(word.strip(string.punctuation)) for word in l])
movies.head()
# Out:
#                          genres    imdb_id  \
# 0   [Animation, Comedy, Family]  tt0114709
# 1  [Adventure, Fantasy, Family]  tt0113497
# 2             [Romance, Comedy]  tt0113228
# 3      [Comedy, Drama, Romance]  tt0114885
# 4                      [Comedy]  tt0113041
#
#                                             overview  \
# 0  [led, by, woodi, andi, toy, live, happili, in,...
# 1  [roll, the, dice, and, unleash, the, excit, wh...
# 2  [still, yell, still, fight, still, readi, for,...
# 3  [friend, are, the, peopl, who, let, you, be, y...
# 4  [just, when, his, world, is, back, to, normal,...
#
#                          title  vote_average  vote_count  movie_id
# 0                    Toy Story           7.7      5415.0       862
# 1                      Jumanji           6.9      2413.0      8844
# 2             Grumpier Old Men           6.5        92.0     15602
# 3            Waiting to Exhale           6.1        34.0     31357
# 4  Father of the Bride Part II           5.7       173.0     11862

# %% [markdown]
# **Cleaning Keywords**

# %%
keywords = pd.read_csv('C:/Coding Projects/Movie-Recommender-Engine/data/keywords.csv')
keywords['keywords'] = keywords['keywords'].apply(lambda element: eval(element))
keywords['movie_id'] = keywords['id']
keywords.drop(columns = ['id'], inplace = True)
keywords.head()
# Out:
#                                             keywords  movie_id
# 0  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...       862
# 1  [{'id': 10090, 'name': 'board game'}, {'id': 1...      8844
# 2  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...     15602
# 3  [{'id': 818, 'name': 'based on novel'}, {'id':...     31357
# 4  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...     11862

# %%
keywords['keywords'] = keywords['keywords'].apply(lambda element: [d['name'] for d in element] if isinstance(element, list) else [])
keywords.head()
# Out:
#                                             keywords  movie_id
# 0  [jealousy, toy, boy, friendship, friends, riva...       862
# 1  [board game, disappearance, based on children'...      8844
# 2  [fishing, best friend, duringcreditsstinger, o...     15602
# 3  [based on novel, interracial relationship, sin...     31357
# 4  [baby, midlife crisis, confidence, aging, daug...     11862

# %%
all_keywords = keywords['keywords'].apply(lambda l: pd.Series(l)).stack().value_counts()
unique_keywords = all_keywords[all_keywords == 1]
unique_keywords
# Out:
# penniless             1
# acab                  1
# remains               1
# ancient tablet        1
# coming home           1
#                      ..
# helping animals       1
# animal agriculture    1
# brother sister        1
# bad boy               1
# biloxi mississippi    1
# Name: count, Length: 8559, dtype: int64

# %%
keywords['keywords'] = keywords['keywords'].apply(lambda l: [element for element in l if element not in unique_keywords.index])
keywords.head()
# Out:
#                                             keywords  movie_id
# 0  [jealousy, toy, boy, friendship, friends, riva...       862
# 1  [board game, disappearance, based on children'...      8844
# 2  [fishing, best friend, duringcreditsstinger, o...     15602
# 3  [based on novel, interracial relationship, sin...     31357
# 4  [baby, midlife crisis, confidence, aging, daug...     11862

# %%
"""Stem the keywords so there are less features in the TF-IDF matrix"""
keywords['keywords'] = keywords['keywords'].apply(lambda l: [stemmer.stem(word) for word in l])

# %%
keywords.head()
# Out:
#                                             keywords  movie_id
# 0  [jealousi, toy, boy, friendship, friend, rival...       862
# 1  [board gam, disappear, based on children's boo...      8844
# 2   [fish, best friend, duringcreditssting, old men]     15602
# 3  [based on novel, interracial relationship, sin...     31357
# 4  [babi, midlife crisi, confid, age, daughter, m...     11862

# %% [markdown]
# **Cleaning credits**

# %%
credits = pd.read_csv('C:/Coding Projects/Movie-Recommender-Engine/data/credits.csv')
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
credits['cast'] = credits['cast'].apply(lambda element: eval(element))
credits['crew'] = credits['crew'].apply(lambda element: eval(element))
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
credits['director'] = credits['crew'].apply(lambda element: [d['name'] for d in element if 'director' in d['job'].lower()] if isinstance(element, list) else [])

"""Turn the director names into a single string not seperated by spaces (otherwise first and last name will be treated as different terms in TF-IDF vectorization)"""

credits['director'] = credits['director'].apply(lambda l: [''.join(fullname.split()) for fullname in l])
credits['director'].head(1).values[0]
# Out:
# ['JohnLasseter', 'AshBrannon', 'WilliamReeves', 'RichQuade']

# %%
"""Find the cast members that only appear in one movie"""

director_name_counts = credits['director'].apply(lambda l: pd.Series(l)).stack().value_counts()
unique_directors = director_name_counts[director_name_counts == 1]
unique_directors.head(30)
unique_directors.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 18002 entries, FredGallo to LuisEsteban
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 18002 non-null  int64
# dtypes: int64(1)
# memory usage: 281.3+ KB

# %%
"""Get rid of the cast members that only appear in one movie (they will not be useful for finding similarities between movies)"""

credits['director'] = credits['director'].apply(lambda l: [name for name in l if name not in unique_directors.index])
credits['director'].head()
# Out:
# 0         [JohnLasseter, AshBrannon]
# 1    [JoeJohnston, ThomasE.Ackerman]
# 2                     [HowardDeutch]
# 3                   [ForestWhitaker]
# 4        [ElliotDavis, CharlesShyer]
# Name: director, dtype: object

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                           director
# 0       [JohnLasseter, AshBrannon]
# 1  [JoeJohnston, ThomasE.Ackerman]
# 2                   [HowardDeutch]
# 3                 [ForestWhitaker]
# 4      [ElliotDavis, CharlesShyer]

# %%
top_3_actors = credits['cast'].apply(lambda l: [d['name'] for d in l][0:3])
top_3_actors = top_3_actors.apply(lambda l: [''.join(fullname.split()) for fullname in l])
top_3_actors.head()
# Out:
# 0                  [TomHanks, TimAllen, DonRickles]
# 1       [RobinWilliams, JonathanHyde, KirstenDunst]
# 2          [WalterMatthau, JackLemmon, Ann-Margret]
# 3    [WhitneyHouston, AngelaBassett, LorettaDevine]
# 4           [SteveMartin, DianeKeaton, MartinShort]
# Name: cast, dtype: object

# %%
credits['top_3_actors'] = top_3_actors
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
#
#                           director  \
# 0       [JohnLasseter, AshBrannon]
# 1  [JoeJohnston, ThomasE.Ackerman]
# 2                   [HowardDeutch]
# 3                 [ForestWhitaker]
# 4      [ElliotDavis, CharlesShyer]
#
#                                      top_3_actors
# 0                [TomHanks, TimAllen, DonRickles]
# 1     [RobinWilliams, JonathanHyde, KirstenDunst]
# 2        [WalterMatthau, JackLemmon, Ann-Margret]
# 3  [WhitneyHouston, AngelaBassett, LorettaDevine]
# 4         [SteveMartin, DianeKeaton, MartinShort]

# %%
credits['movie_id'] = credits['id']
credits.drop(columns = ['id'], inplace = True)
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                           director  \
# 0       [JohnLasseter, AshBrannon]
# 1  [JoeJohnston, ThomasE.Ackerman]
# 2                   [HowardDeutch]
# 3                 [ForestWhitaker]
# 4      [ElliotDavis, CharlesShyer]
#
#                                      top_3_actors  movie_id
# 0                [TomHanks, TimAllen, DonRickles]       862
# 1     [RobinWilliams, JonathanHyde, KirstenDunst]      8844
# 2        [WalterMatthau, JackLemmon, Ann-Margret]     15602
# 3  [WhitneyHouston, AngelaBassett, LorettaDevine]     31357
# 4         [SteveMartin, DianeKeaton, MartinShort]     11862

# %%
#Director should be weighted more than other cast members
credits['director'] = credits['director'] * 3
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': 'Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
#                                             director  \
# 0  [JohnLasseter, AshBrannon, JohnLasseter, AshBr...
# 1  [JoeJohnston, ThomasE.Ackerman, JoeJohnston, T...
# 2         [HowardDeutch, HowardDeutch, HowardDeutch]
# 3   [ForestWhitaker, ForestWhitaker, ForestWhitaker]
# 4  [ElliotDavis, CharlesShyer, ElliotDavis, Charl...
#
#                                      top_3_actors  movie_id
# 0                [TomHanks, TimAllen, DonRickles]       862
# 1     [RobinWilliams, JonathanHyde, KirstenDunst]      8844
# 2        [WalterMatthau, JackLemmon, Ann-Margret]     15602
# 3  [WhitneyHouston, AngelaBassett, LorettaDevine]     31357
# 4         [SteveMartin, DianeKeaton, MartinShort]     11862

# %% [markdown]
# **Merge Keywords and Credits into Movies**

# %%
movies = movies.merge(keywords, on = 'movie_id', how = 'inner')
movies.head()
# Out:
#                          genres    imdb_id  \
# 0   [Animation, Comedy, Family]  tt0114709
# 1  [Adventure, Fantasy, Family]  tt0113497
# 2             [Romance, Comedy]  tt0113228
# 3      [Comedy, Drama, Romance]  tt0114885
# 4                      [Comedy]  tt0113041
#
#                                             overview  \
# 0  [led, by, woodi, andi, toy, live, happili, in,...
# 1  [roll, the, dice, and, unleash, the, excit, wh...
# 2  [still, yell, still, fight, still, readi, for,...
# 3  [friend, are, the, peopl, who, let, you, be, y...
# 4  [just, when, his, world, is, back, to, normal,...
#
#                          title  vote_average  vote_count  movie_id  \
# 0                    Toy Story           7.7      5415.0       862
# 1                      Jumanji           6.9      2413.0      8844
# 2             Grumpier Old Men           6.5        92.0     15602
# 3            Waiting to Exhale           6.1        34.0     31357
# 4  Father of the Bride Part II           5.7       173.0     11862
#
#                                             keywords
# 0  [jealousi, toy, boy, friendship, friend, rival...
# 1  [board gam, disappear, based on children's boo...
# 2   [fish, best friend, duringcreditssting, old men]
# 3  [based on novel, interracial relationship, sin...
# 4  [babi, midlife crisi, confid, age, daughter, m...

# %%
movies = movies.merge(credits.loc[:, ['movie_id', 'top_3_actors', 'director']], on='movie_id', how='left')
movies['top_3_actors'] = movies['top_3_actors'].apply(lambda x: x if isinstance(x, list) else [])
movies.head()
# Out:
#                          genres    imdb_id  \
# 0   [Animation, Comedy, Family]  tt0114709
# 1  [Adventure, Fantasy, Family]  tt0113497
# 2             [Romance, Comedy]  tt0113228
# 3      [Comedy, Drama, Romance]  tt0114885
# 4                      [Comedy]  tt0113041
#
#                                             overview  \
# 0  [led, by, woodi, andi, toy, live, happili, in,...
# 1  [roll, the, dice, and, unleash, the, excit, wh...
# 2  [still, yell, still, fight, still, readi, for,...
# 3  [friend, are, the, peopl, who, let, you, be, y...
# 4  [just, when, his, world, is, back, to, normal,...
#
#                          title  vote_average  vote_count  movie_id  \
# 0                    Toy Story           7.7      5415.0       862
# 1                      Jumanji           6.9      2413.0      8844
# 2             Grumpier Old Men           6.5        92.0     15602
# 3            Waiting to Exhale           6.1        34.0     31357
# 4  Father of the Bride Part II           5.7       173.0     11862
#
#                                             keywords  \
# 0  [jealousi, toy, boy, friendship, friend, rival...
# 1  [board gam, disappear, based on children's boo...
# 2   [fish, best friend, duringcreditssting, old men]
# 3  [based on novel, interracial relationship, sin...
# 4  [babi, midlife crisi, confid, age, daughter, m...
#
#                                      top_3_actors  \
# 0                [TomHanks, TimAllen, DonRickles]
# 1     [RobinWilliams, JonathanHyde, KirstenDunst]
# 2        [WalterMatthau, JackLemmon, Ann-Margret]
# 3  [WhitneyHouston, AngelaBassett, LorettaDevine]
# 4         [SteveMartin, DianeKeaton, MartinShort]
#
#                                             director
# 0  [JohnLasseter, AshBrannon, JohnLasseter, AshBr...
# 1  [JoeJohnston, ThomasE.Ackerman, JoeJohnston, T...
# 2         [HowardDeutch, HowardDeutch, HowardDeutch]
# 3   [ForestWhitaker, ForestWhitaker, ForestWhitaker]
# 4  [ElliotDavis, CharlesShyer, ElliotDavis, Charl...

# %%
movies.head()
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46479 entries, 0 to 46478
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genres        46479 non-null  object
#  1   imdb_id       46479 non-null  object
#  2   overview      46479 non-null  object
#  3   title         46475 non-null  object
#  4   vote_average  46475 non-null  float64
#  5   vote_count    46475 non-null  float64
#  6   movie_id      46479 non-null  int64
#  7   keywords      46479 non-null  object
#  8   top_3_actors  46479 non-null  object
#  9   director      46479 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# **Create the Cosine Similarity Matrix between movies**

# %%
movies.head()
"""metadata_dump = movies['overview'] + movies['genres'] + movies['keywords'] + movies['top_3_actors'] + movies['director']
movies['metadata_dump'] = metadata_dump.cumsum()
movies.drop(columns = ['overview', 'genres', 'keywords', 'top_3_actors', 'director'], inplace = True)"""
# Out:
# "metadata_dump = movies['overview'] + movies['genres'] + movies['keywords'] + movies['top_3_actors'] + movies['director']\nmovies['metadata_dump'] = metadata_dump.cumsum()\nmovies.drop(columns = ['overview', 'genres', 'keywords', 'top_3_actors', 'director'], inplace = True)"

# %%
#movies.apply(sum, axis = 1)

# %%
movies['metadata_dump'] = pd.Series(dtype=str)

fields = ['overview', 'genres', 'keywords', 'top_3_actors', 'director']
def generate_metadata_dump_entry():
    for index in movies.index:
        res =  ' '.join(' '.join(movies.at[index, field]) for field in fields)
        movies.at[index, 'metadata_dump'] = res

        for field in fields:
            movies.at[index, field] = ''

generate_metadata_dump_entry()

# %%
movies = movies.drop(columns = fields)
movies.head()
# Out:
#      imdb_id                        title  vote_average  vote_count  movie_id  \
# 0  tt0114709                    Toy Story           7.7      5415.0       862
# 1  tt0113497                      Jumanji           6.9      2413.0      8844
# 2  tt0113228             Grumpier Old Men           6.5        92.0     15602
# 3  tt0114885            Waiting to Exhale           6.1        34.0     31357
# 4  tt0113041  Father of the Bride Part II           5.7       173.0     11862
#
#                                        metadata_dump
# 0  led by woodi andi toy live happili in his room...
# 1  roll the dice and unleash the excit when sibl ...
# 2  still yell still fight still readi for love a ...
# 3  friend are the peopl who let you be yourself a...
# 4  just when his world is back to normal he in fo...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words = 'english', ngram_range = (1, 2), min_df = 3)
dtm = tfidf_vectorizer.fit_transform(movies['metadata_dump'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim_matrix = pd.DataFrame(cosine_similarity(dtm, dense_output = True))
cosine_sim_matrix.index = movies.index
cosine_sim_matrix.columns = movies.index
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[108], line 2
#       1 from sklearn.metrics.pairwise import cosine_similarity
# ----> 2 cosine_sim_matrix = pd.DataFrame(cosine_similarity(dtm, dense_output = True))
#       3 cosine_sim_matrix.index = movies.index
#       4 cosine_sim_matrix.columns = movies.index
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\sklearn\metrics\pairwise.py:1736, in cosine_similarity(X, Y, dense_output)
#    1733 else:
#    1734     Y_normalized = normalize(Y, copy=True)
# -> 1736 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1738 return K
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\sklearn\utils\extmath.py:203, in safe_sparse_dot(a, b, dense_output)
#     201         ret = xp.tensordot(a, b, axes=[-1, b_axis])
#     202 else:
# --> 203     ret = a @ b
#     205 if (
#     206     sparse.issparse(a)
#     207     and sparse.issparse(b)
#     208     and dense_output
#     209     and hasattr(ret, "toarray")
#     210 ):
#     211     return ret.toarray()
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\scipy\sparse\_base.py:905, in _spbase.__matmul__(self, other)
#     902 if isscalarlike(other):
#     903     raise ValueError("Scalar operands are not allowed, "
#     904                      "use '*' instead")
# --> 905 return self._matmul_dispatch(other)
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\scipy\sparse\_base.py:809, in _spbase._matmul_dispatch(self, other)
#     805     if N != other.shape[0]:
#     806         raise ValueError(
#     807             f"{err_prefix} (n,k={N}),(k={other.shape[0]},m)->(n,m)"
#     808         )
# --> 809     return self._matmul_sparse(other)
#     811 # If it's a list or whatever, treat it like an array
#     812 other_a = np.asanyarray(other)
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\scipy\sparse\_compressed.py:460, in _cs_matrix._matmul_sparse(self, other)
#     458 indptr = np.empty(M + 1, dtype=idx_dtype)
#     459 indices = np.empty(nnz, dtype=idx_dtype)
# --> 460 data = np.empty(nnz, dtype=upcast(self.dtype, other.dtype))
#     462 csr_matmat(M, N,
#     463            s_indptr, s_indices, s.data,
#     464            o_indptr, o_indices, o.data,
#     465            indptr, indices, data)
#     467 if new_shape == ():
#
# MemoryError: Unable to allocate 10.1 GiB for an array with shape (1351112717,) and data type float64

# %%
cosine_sim_matrix['movie_id'] = movies.index
columns = ['movie_id'] +[col_name for col_name in cosine_sim_matrix.columns if col_name != 'movie_id']
cosine_sim_matrix = cosine_sim_matrix[columns]
cosine_sim_matrix.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 cosine_sim_matrix['movie_id'] = movies.index
#       2 columns = ['movie_id'] +[col_name for col_name in cosine_sim_matrix.columns if col_name != 'movie_id']
#       3 cosine_sim_matrix = cosine_sim_matrix[columns]
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\pandas\core\frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)   4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
#    4534         and not isinstance(value.dtype, ExtensionDtype)
#    4535     ):
#    4536         # broadcast across multiple columns if necessary
#    4537         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\pandas\core\frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
#    5276     isinstance(value, Index)
#    5277     and value.dtype == "object"
#    (...)   5280     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5281     # this deprecation
#
# File c:\Coding Projects\Movie-Recommender-Engine\.venv\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (46475) does not match length of index (46479)

# %% [markdown]
# **Create the correlation matrix for movie ratings**

# %%
movie_ratings = pd.read_csv(f'C:/Coding Projects/Movie-Recommender-Engine/data/ratings_small.csv')
movie_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movie_ratings = movie_ratings.pivot_table(index = 'userId', columns = 'movieId', values = 'rating')
movie_ratings.head()
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     4.0     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10      ...  161084  161155  161594  161830  161918  161944  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  162376  162542  162672  163949
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
#
# [5 rows x 9066 columns]

# %%
movie_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 671 entries, 1 to 671
# Columns: 9066 entries, 1 to 163949
# dtypes: float64(9066)
# memory usage: 46.4 MB

# %%
correlation_matrix = movie_ratings.corr(method = 'pearson', min_periods = 7)
correlation_matrix.head()
# Out:
# movieId    1         2         3         4         5         6         7       \
# movieId
# 1        1.000000  0.363256  0.255080 -0.031564  0.279521  0.030998  0.350519
# 2        0.363256  1.000000  0.187217       NaN  0.035446 -0.019630  0.425928
# 3        0.255080  0.187217  1.000000       NaN  0.560180 -0.075918  0.050120
# 4       -0.031564       NaN       NaN  1.000000       NaN       NaN       NaN
# 5        0.279521  0.035446  0.560180       NaN  1.000000  0.383228  0.012493
#
# movieId  8         9         10      ...  161084  161155  161594  161830  \
# movieId                              ...
# 1           NaN -0.312002  0.096792  ...     NaN     NaN     NaN     NaN
# 2           NaN       NaN  0.438066  ...     NaN     NaN     NaN     NaN
# 3           NaN  0.496904  0.164039  ...     NaN     NaN     NaN     NaN
# 4           NaN       NaN       NaN  ...     NaN     NaN     NaN     NaN
# 5           NaN  0.225689  0.077864  ...     NaN     NaN     NaN     NaN
#
# movieId  161918  161944  162376  162542  162672  163949
# movieId
# 1           NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 9066 columns]

# %%
correlation_matrix['movie_id'] = correlation_matrix.index
columns = ['movie_id'] + [col_name for col_name in correlation_matrix.columns if col_name != 'movie_id']
correlation_matrix = correlation_matrix[columns]

correlation_matrix.index.name = None
correlation_matrix.columns.name = None

correlation_matrix.head()
# Out:
#    movie_id         1         2         3         4         5         6  \
# 1         1  1.000000  0.363256  0.255080 -0.031564  0.279521  0.030998
# 2         2  0.363256  1.000000  0.187217       NaN  0.035446 -0.019630
# 3         3  0.255080  0.187217  1.000000       NaN  0.560180 -0.075918
# 4         4 -0.031564       NaN       NaN  1.000000       NaN       NaN
# 5         5  0.279521  0.035446  0.560180       NaN  1.000000  0.383228
#
#           7   8         9  ...  161084  161155  161594  161830  161918  \
# 1  0.350519 NaN -0.312002  ...     NaN     NaN     NaN     NaN     NaN
# 2  0.425928 NaN       NaN  ...     NaN     NaN     NaN     NaN     NaN
# 3  0.050120 NaN  0.496904  ...     NaN     NaN     NaN     NaN     NaN
# 4       NaN NaN       NaN  ...     NaN     NaN     NaN     NaN     NaN
# 5  0.012493 NaN  0.225689  ...     NaN     NaN     NaN     NaN     NaN
#
#    161944  162376  162542  162672  163949
# 1     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 9067 columns]

# %% [markdown]
# **Simplify the movies metadata further**

# %%
movies = movies.drop(columns = 'metadata_dump')
movies.head()
# Out:
#      imdb_id                        title  vote_average  vote_count  movie_id
# 0  tt0114709                    Toy Story           7.7      5415.0       862
# 1  tt0113497                      Jumanji           6.9      2413.0      8844
# 2  tt0113228             Grumpier Old Men           6.5        92.0     15602
# 3  tt0114885            Waiting to Exhale           6.1        34.0     31357
# 4  tt0113041  Father of the Bride Part II           5.7       173.0     11862

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46475 entries, 0 to 46478
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   imdb_id       46475 non-null  object
#  1   title         46475 non-null  object
#  2   vote_average  46475 non-null  float64
#  3   vote_count    46475 non-null  float64
#  4   movie_id      46475 non-null  int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.1+ MB
